# %%
import cartopy
import matplotlib.pyplot as mp

# %%
crs = cartopy.crs.InterruptedGoodeHomolosine()

fig = mp.figure()
ax = fig.add_axes(111, projection=crs)
ax.add_feature(cartopy.feature.COASTLINE, color='#000', linewidth=1)
ax.spines['geo'].set_edgecolor('#000')
ax.spines['geo'].set_linewidth(1)
fig.tight_layout()
fig.savefig('../docs/homolosine.svg', transparent=True, bbox_inches='tight')
# Out:
# /Users/baird/miniconda3/envs/gem/lib/python3.11/site-packages/cartopy/mpl/style.py:76: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %%
crs = cartopy.crs.InterruptedGoodeHomolosine()

fig = mp.figure()
ax = fig.add_axes(111, projection=crs)
ax.add_feature(cartopy.feature.LAND, color='#000', linewidth=0)
ax.spines['geo'].set_edgecolor('#000')
ax.spines['geo'].set_linewidth(1)
fig.tight_layout()
fig.savefig('../docs/homolosine-filled.svg', transparent=True, bbox_inches='tight')

# %%
crs = cartopy.crs.InterruptedGoodeHomolosine()

fig = mp.figure()
ax = fig.add_axes(111, projection=crs)
ax.add_feature(cartopy.feature.LAND, color='cyan', linewidth=0)
ax.spines['geo'].set_edgecolor('cyan')
ax.spines['geo'].set_linewidth(1)
fig.tight_layout()
fig.savefig('../docs/homolosine-filled-cyan.svg', transparent=True, bbox_inches='tight')

# %%
crs = cartopy.crs.InterruptedGoodeHomolosine()

fig = mp.figure()
ax = fig.add_axes(111, projection=crs)
ax.add_feature(cartopy.feature.LAND, color='magenta', linewidth=0)
ax.spines['geo'].set_edgecolor('magenta')
ax.spines['geo'].set_linewidth(1)
fig.tight_layout()
fig.savefig('../docs/homolosine-filled-magenta.svg', transparent=True, bbox_inches='tight')

# %%
crs = cartopy.crs.InterruptedGoodeHomolosine()

fig = mp.figure()
ax = fig.add_axes(111, projection=crs)
ax.add_feature(cartopy.feature.LAND, color='yellow', linewidth=0)
ax.spines['geo'].set_edgecolor('yellow')
ax.spines['geo'].set_linewidth(1)
fig.tight_layout()
fig.savefig('../docs/homolosine-filled-yellow.svg', transparent=True, bbox_inches='tight')
